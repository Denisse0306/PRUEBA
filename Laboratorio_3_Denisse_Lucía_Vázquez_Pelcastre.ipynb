# %% [markdown]
# <a href="https://colab.research.google.com/github/Denisse0306/PRUEBA/blob/main/Laboratorio_3_Denisse_Luc%C3%ADa_V%C3%A1zquez_Pelcastre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

import matplotlib.pyplot as plt

path ="/content/drive/MyDrive/Conjunto de datos/atenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujeres.csv - atenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujeres.csv.csv"

df = pd.read_csv(path)

edad = df["usuaria_edad"]

dist = edad.value_counts()

plt.bar(dist.index, dist.values)

plt.xlim(0, 100)

plt.show()
# Out:
# <ipython-input-3-33c2fc11febf>:7: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd

import matplotlib.pyplot as plt
path ="/content/drive/MyDrive/Conjunto de datos/atenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujeres.csv - atenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujeres.csv.csv"

df = pd.read_csv(path)

conteo =df["usuaria_estado_civil"].value_counts()

plt.barh( conteo.index, conteo)

plt.show()
# Out:
# <ipython-input-5-cea18b3e32d1>:6: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd

import matplotlib.pyplot as plt
path ="/content/drive/MyDrive/Conjunto de datos/atenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujeres.csv - atenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujeres.csv.csv"

df = pd.read_csv(path)

conteo =df["año"].value_counts()

plt.barh( conteo.index, conteo)

plt.show()
# Out:
# <ipython-input-6-7453d78aee67>:6: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
